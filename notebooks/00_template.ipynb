# %% [markdown]
# # Example Notebook Template
#
# **Author:** [Your Name/Initials]
# **Date:** [Date]
# **Purpose:** [Brief description of what this notebook does]
#
# ## Overview
#
# [Provide context and objectives for this notebook]

# %% [markdown]
# ## Setup

# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Project imports
# from src.utils import load_data

# Configuration
# %matplotlib inline
sns.set_style('whitegrid')
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Load Data

# %%
# Load your data here
# df = pd.read_csv('../data/raw/your_data.csv')

# %% [markdown]
# ## Analysis
#
# [Add your analysis sections here]

# %%
# Your analysis code

# %% [markdown]
# ## Conclusions
#
# [Summarize your findings]
